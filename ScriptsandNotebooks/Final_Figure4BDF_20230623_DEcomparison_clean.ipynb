# %%
require(ggplot2)
library(ggrepel)
require(tidyverse)
library("VennDiagram")
# Out:
# Loading required package: ggplot2
#
# Loading required package: tidyverse
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ lubridate 1.9.2     ✔ tibble    3.2.0
# ✔ purrr     1.0.1     ✔ tidyr     1.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: grid
#
# Loading required package: futile.logger

# %%
setwd('/gpfs/group/home/salee/Spatial_CMP')

# %% [markdown]
# ## Figure 4B

# %%
DEfile1 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_ICMP__Control_Y_OL_N_RE_PID_Institute_Fixation.interval_KR_Y2023-06-22conditionICMP_conditionControl.csv"
DEfile2 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_NES_HCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2023-06-22conditionNES_HCMP_conditionControl.csv"
DEfile3 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_ES_HCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2023-06-22conditionES_HCMP_conditionControl.csv"
DEfile4 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_DCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2023-06-22conditionDCMP_conditionControl.csv"
DEfile5 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_NES_HCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2023-06-22conditionNES_HCMP_conditionControl.csv"
DEfile6 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_ICMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2023-06-22conditionICMP_conditionControl.csv"
DEfile7 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_ES_HCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2023-06-22conditionES_HCMP_conditionControl.csv"
DEfile8 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_DCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2023-06-22conditionDCMP_conditionControl.csv"

# %%
# # needs DE file

# DEfile1 = "DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_ICMP__Control_Y_OL_N_RE_PID_Institute_Fixation.interval_KR_Y2022-10-19conditionICMP_conditionControl.csv"
# DEfile2 = "DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_NES_HCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2022-10-18conditionNES_HCMP_conditionControl.csv"
# DEfile3 = "DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_ES_HCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2022-10-18conditionES_HCMP_conditionControl.csv"
# DEfile4 = "DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_DCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2022-10-18conditionDCMP_conditionControl.csv"
# DEfile5 = "DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_NES_HCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2022-10-18conditionNES_HCMP_conditionControl.csv"
# DEfile6 = "DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_ICMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2022-10-18conditionICMP_conditionControl.csv"
# DEfile7 = "DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_ES_HCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2022-10-18conditionES_HCMP_conditionControl.csv"
# DEfile8 = "DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_DCMP__Control_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2022-10-18conditionDCMP_conditionControl.csv"

# %%
DE1 <- read.csv(file.path(getwd(), "results", paste0(DEfile1)), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE2 <- read.csv(file.path(getwd(), "results", paste0(DEfile2)), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE3 <- read.csv(file.path(getwd(), "results", paste0(DEfile3)), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE4 <- read.csv(file.path(getwd(), "results", paste0(DEfile4)), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE5 <- read.csv(file.path(getwd(), "results", paste0(DEfile5)), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE6 <- read.csv(file.path(getwd(), "results", paste0(DEfile6)), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE7 <- read.csv(file.path(getwd(), "results", paste0(DEfile7)), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE8 <- read.csv(file.path(getwd(), "results", paste0(DEfile8)), row.names = 1, header = TRUE, stringsAsFactors=FALSE)

# %%
for (i in 1:4){
    tmp <- gsub("fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_", "", get(paste0("DEfile", i)))
    tmp2 <- gsub("_ROI_large_Vent_LV_DsSelect", "", tmp)
    tmp3 <- sub("_Y_OL.*", "", tmp2, perl=TRUE)
    tmp4 <-get(paste0("DE", i))
    tmp4 <- tmp4 %>% mutate(COI = tmp3) 
    assign(paste0("DE", i), tmp4)
}

# %%
for (i in 5:8){
    tmp <- gsub("fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_", "", get(paste0("DEfile", i)))
    tmp2 <- gsub("_ROI_large_Vent_LV_DsSelect", "", tmp)
    tmp3 <- sub("_Y_OL.*", "", tmp2, perl=TRUE)
    tmp4 <-get(paste0("DE", i))
    tmp4 <- tmp4 %>% mutate(COI = tmp3) 
    assign(paste0("DE", i), tmp4)
}

# %%
for (i in 1:8){
    tmp4 <-get(paste0("DE", i))
    tmp4 <- tmp4 %>% mutate(Index = 1:nrow(tmp4)) 
    assign(paste0("DE", i), tmp4)
}

# %%
for (i in 1:8){
    tmp4 <-get(paste0("DE", i))
    tmp4$PosIndex[tmp4$logFC > 0 & tmp4$adj.P.Val < 0.05]<-1:nrow(tmp4[tmp4$logFC > 0 & tmp4$adj.P.Val < 0.05,])
    tmp4$NegIndex[tmp4$logFC < 0 & tmp4$adj.P.Val < 0.05]<-1:nrow(tmp4[tmp4$logFC < 0 & tmp4$adj.P.Val < 0.05,])
    assign(paste0("DE", i), tmp4)
}

# %%
# DE_Noseg<-rbind(DE1, DE2, DE3)
# DE_eachcell<-rbind(DE4, DE5, DE6)
# DE_othercell<-rbind(DE7, DE8, DE9)
DE_total1 <- rbind(DE1, DE2, DE3, DE4, DE5, DE6, DE7, DE8)
# DE_total2 <- rbind(DE11, DE12, DE13, DE14, DE15, DE16)

# %%
unique(DE_total1$COI )
# Out:
# [1] "Endothelial_cells_ICMP__Control"     "Endothelial_cells_NES_HCMP__Control"
# [3] "Endothelial_cells_ES_HCMP__Control"  "Endothelial_cells_DCMP__Control"
# [5] "Cardiomyocytes_NES_HCMP__Control"    "Cardiomyocytes_ICMP__Control"
# [7] "Cardiomyocytes_ES_HCMP__Control"     "Cardiomyocytes_DCMP__Control"

# %%
DE_total1$diffexpressed <- "NO"
DE_total1$diffexpressed[DE_total1$logFC > 0 & DE_total1$adj.P.Val < 0.05] <- "UP"
DE_total1$diffexpressed[DE_total1$logFC < 0 & DE_total1$adj.P.Val < 0.05] <- "DOWN"
DE_total1$delabel <- NA
DE_total1$delabel[DE_total1$PosIndex %in% c(1:5) | DE_total1$NegIndex %in% c(1:5)] <- DE_total1$SYMBOL[DE_total1$PosIndex %in% c(1:5) | DE_total1$NegIndex %in% c(1:5)]
DE_total1$COI <- factor(DE_total1$COI, levels=c('Cardiomyocytes_DCMP__Control', 
                                               'Cardiomyocytes_ICMP__Control',
                                               'Cardiomyocytes_ES_HCMP__Control',
                                               'Cardiomyocytes_NES_HCMP__Control',
                                               'Endothelial_cells_DCMP__Control',
                                               'Endothelial_cells_ICMP__Control',
                                               'Endothelial_cells_ES_HCMP__Control', 
                                               'Endothelial_cells_NES_HCMP__Control'))

# %%
DE_total1$COI <- recode_factor(DE_total1$COI, 
                               Cardiomyocytes_DCMP__Control="CMC - DCMP vs Control",  
                               Cardiomyocytes_ICMP__Control='CMC - ICMP vs Control',
                               Cardiomyocytes_ES_HCMP__Control='CMC - HCMPrEF vs Control',
                               Cardiomyocytes_NES_HCMP__Control='CMC - HCMPpEF vs Control',
                               Endothelial_cells_DCMP__Control='EC - DCMP vs Control',
                               Endothelial_cells_ICMP__Control='EC - ICMP vs Control',
                               Endothelial_cells_ES_HCMP__Control='EC - HCMPrEF vs Control', 
                               Endothelial_cells_NES_HCMP__Control='EC - HCMPpEF vs Control'
                               )

# %%
DE_total1[DE_total1$COI=='EC - DCMP vs Control' & DE_total1$PosIndex%in%c(1:10),]
# Out:
#        SYMBOL ENTREZID GENENAME                       logFC     AveExpr
# ID23   ID2      3398   inhibitor of DNA binding 2     0.6828204 7.229801
# TYW53  TYW5   129450   tRNA-yW synthesizing protein 5 1.1760047 5.404188
# MMP153 MMP15    4324   matrix metallopeptidase 15     1.0950914 5.642062
#        t        P.Value      adj.P.Val   B          z.std
# ID23   4.648999 4.170659e-06 0.007626347  0.1910403 4.602691
# TYW53  4.586346 1.094081e-05 0.015560270 -1.0043948 4.397692
# MMP153 4.199606 3.706901e-05 0.036498717 -0.8821779 4.125028
#        COI                  Index PosIndex NegIndex diffexpressed delabel
# ID23   EC - DCMP vs Control  7    1        NA       UP            ID2
# TYW53  EC - DCMP vs Control  9    2        NA       UP            TYW5
# MMP153 EC - DCMP vs Control 13    3        NA       UP            MMP15

# %%
options(repr.plot.width=18, repr.plot.height=5)

# %%
ggplot(data=DE_total1, aes(x=COI, y=(-log10(adj.P.Val))*(sign(logFC)), col=diffexpressed, label=delabel)) +
geom_jitter(width=0.02) +
theme_minimal() +
geom_text_repel(size=5, max.overlaps=100
) +
scale_color_manual(values=c("blue", "black", "red"), labels=c('Down-regulated', 'No change', 'Up-regulated')) +
geom_hline(yintercept=c(-log10(0.05), log10(0.05)), col="red") +
geom_hline(yintercept=0, col="black") +
theme(axis.text.x=element_text(angle = 10, hjust=0.5, size=14,face="bold"),
        axis.title=element_text(size=14,face="bold"),
     legend.title=element_blank(),
     legend.text = element_text(size=12),
     ) +
xlab("") +
guides(color = guide_legend(override.aes = list(size = 8)))
# Out:
# Warning message:
# “Removed 102326 rows containing missing values (`geom_text_repel()`).”
# plot without title

# %%
for (i in levels(DE_total1$COI)){
    posde<-dim(DE_total1[DE_total1$COI==i&is.na(DE_total1$PosIndex)==FALSE,])[1]
    negde<-dim(DE_total1[DE_total1$COI==i&is.na(DE_total1$NegIndex)==FALSE,])[1]
    print(paste(i, " positive de = ", posde, " negative de = ", negde))
    }
# Out:
# [1] "CMC - DCMP vs Control  positive de =  72  negative de =  76"
# [1] "CMC - ICMP vs Control  positive de =  23  negative de =  48"
# [1] "CMC - HCMPrEF vs Control  positive de =  110  negative de =  109"
# [1] "CMC - HCMPpEF vs Control  positive de =  415  negative de =  399"
# [1] "EC - DCMP vs Control  positive de =  3  negative de =  10"
# [1] "EC - ICMP vs Control  positive de =  15  negative de =  13"
# [1] "EC - HCMPrEF vs Control  positive de =  1  negative de =  5"
# [1] "EC - HCMPpEF vs Control  positive de =  90  negative de =  75"

# %% [markdown]
# # Figure 4D

# %%
DEfile11 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_ICMP__NES_HCMP_Y_OL_N_RE_PID_Institute_Fixation.interval_KR_Y2023-06-23conditionICMP_conditionNES_HCMP"
DEfile12 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_ICMP__ES_HCMP_Y_OL_pcaplot_outlier_RE_PID_Institute_Fixation.interval_KR_Y2023-06-23conditionICMP_conditionES_HCMP"
DEfile13 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_ES_HCMP__NES_HCMP_Y_OL_pcaplot_outlier_RE_PID_Fixation.interval_KR_Y2023-06-23conditionES_HCMP_conditionNES_HCMP"
DEfile14 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_DCMP__NES_HCMP_Y_OL_pcaplot_outlier_RE_PID_Fixation.interval_KR_Y2023-06-23conditionDCMP_conditionNES_HCMP"
DEfile15 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_DCMP__ICMP_Y_OL_pcaplot_outlier_RE_PID_Fixation.interval_KR_Y2023-06-23conditionICMP_conditionDCMP"
DEfile16 = "fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Cardiomyocytes_ROI_large_Vent_LV_DsSelect_DCMP__ES_HCMP_Y_OL_pcaplot_outlier_RE_PID_Fixation.interval_KR_Y2023-06-23conditionES_HCMP_conditionDCMP"

# %%
DE11 <- read.csv(file.path(getwd(), "results", paste0(DEfile11, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE12 <- read.csv(file.path(getwd(), "results", paste0(DEfile12, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE13 <- read.csv(file.path(getwd(), "results", paste0(DEfile13, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE14 <- read.csv(file.path(getwd(), "results", paste0(DEfile14, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE15 <- read.csv(file.path(getwd(), "results", paste0(DEfile15, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE16 <- read.csv(file.path(getwd(), "results", paste0(DEfile16, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)

# %%
for (i in 11:16){
    tmp <- gsub("fSupplT5_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_", "", get(paste0("DEfile", i)))
    tmp2 <- gsub("_ROI_large_Vent_LV_DsSelect.*23", "", tmp)
    tmp3 <- gsub("condition", "_", tmp2)
    tmp3 <- gsub(".csv", "", tmp3)
    tmp4 <-get(paste0("DE", i))
    tmp4 <- tmp4 %>% mutate(COI = tmp3) 
    assign(paste0("DE", i), tmp4)
}

# %%
for (i in 11:16){
    tmp4 <-get(paste0("DE", i))
    tmp4 <- tmp4 %>% mutate(Index = 1:nrow(tmp4)) 
    assign(paste0("DE", i), tmp4)
}

# %%
for (i in 11:16){
    tmp4 <-get(paste0("DE", i))
    tmp4$PosIndex[tmp4$logFC > 0 & tmp4$adj.P.Val < 0.05]<-1:nrow(tmp4[tmp4$logFC > 0 & tmp4$adj.P.Val < 0.05,])
    tmp4$NegIndex[tmp4$logFC < 0 & tmp4$adj.P.Val < 0.05]<-1:nrow(tmp4[tmp4$logFC < 0 & tmp4$adj.P.Val < 0.05,])
    assign(paste0("DE", i), tmp4)
}

# %%
# DE_Noseg<-rbind(DE1, DE2, DE3)
# DE_eachcell<-rbind(DE4, DE5, DE6)
# DE_othercell<-rbind(DE7, DE8, DE9)
DE_total2 <- rbind(DE11, DE12, DE13, DE14, DE15, DE16)

# %%
unique(DE_total2$COI )
# Out:
# [1] "Cardiomyocytes_ICMP__NES_HCMP"    "Cardiomyocytes_ICMP__ES_HCMP"
# [3] "Cardiomyocytes_ES_HCMP__NES_HCMP" "Cardiomyocytes_DCMP__NES_HCMP"
# [5] "Cardiomyocytes_ICMP__DCMP"        "Cardiomyocytes_ES_HCMP__DCMP"

# %%
DE_total2$diffexpressed <- "NO"
DE_total2$diffexpressed[DE_total2$logFC > 0 & DE_total2$adj.P.Val < 0.05] <- "UP"
DE_total2$diffexpressed[DE_total2$logFC < 0 & DE_total2$adj.P.Val < 0.05] <- "DOWN"
DE_total2$delabel <- NA
DE_total2$delabel[DE_total2$diffexpressed!="NO"] <- DE_total2$SYMBOL[DE_total2$diffexpressed!="NO"]
DE_total2$COI <- factor(DE_total2$COI, levels=c('Cardiomyocytes_ICMP__DCMP', 
                                               'Cardiomyocytes_ES_HCMP__DCMP',
                                               'Cardiomyocytes_ICMP__ES_HCMP',
                                               'Cardiomyocytes_DCMP__NES_HCMP',
                                               'Cardiomyocytes_ICMP__NES_HCMP',
                                               'Cardiomyocytes_ES_HCMP__NES_HCMP'))

# %%
DE_total2$COI <- recode_factor(DE_total2$COI, 
                               Cardiomyocytes_ICMP__DCMP = "CMC - ICMP vs DCMP", 
                                Cardiomyocytes_ES_HCMP__DCMP = "CMC - HCMPrEF vs DCMP",
                                Cardiomyocytes_ICMP__ES_HCMP = "CMC - ICMP vs HCMPrEF",
                                Cardiomyocytes_DCMP__NES_HCMP = "CMC - DCMP vs HCMPpEF",
                                Cardiomyocytes_ICMP__NES_HCMP = "CMC - ICMP vs HCMPpEF",
                                Cardiomyocytes_ES_HCMP__NES_HCMP = "CMC - HCMPrEF vs HCMPpEF"
                               )

# %%
options(repr.plot.width=18, repr.plot.height=5)

# %%
ggplot(data=DE_total2, aes(x=COI, y=(-log10(adj.P.Val))*(sign(logFC)), col=diffexpressed, label=delabel)) +
geom_jitter(width=0.02) +
theme_minimal() +
geom_text_repel(size=5
) +
scale_color_manual(values=c("blue", "black", "red"), labels=c('Down-regulated', 'No change', 'Up-regulated')) +
geom_hline(yintercept=c(-log10(0.05), log10(0.05)), col="red") +
geom_hline(yintercept=0, col="black") +
theme(axis.text.x=element_text(angle = 10, hjust=0.5, size=14,face="bold"),
        axis.title=element_text(size=14,face="bold"),
     legend.title=element_blank(),
     legend.text = element_text(size=12),
     ) +
xlab("") +
guides(color = guide_legend(override.aes = list(size = 8)))
# Out:
# Warning message:
# “Removed 76079 rows containing missing values (`geom_text_repel()`).”
# Warning message:
# “ggrepel: 707 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
for (i in levels(DE_total2$COI)){
    posde<-dim(DE_total2[DE_total2$COI==i&is.na(DE_total2$PosIndex)==FALSE,])[1]
    negde<-dim(DE_total2[DE_total2$COI==i&is.na(DE_total2$NegIndex)==FALSE,])[1]
    print(paste(i, " positive de = ", posde, " negative de = ", negde))
    }
# Out:
# [1] "CMC - ICMP vs DCMP  positive de =  0  negative de =  2"
# [1] "CMC - HCMPrEF vs DCMP  positive de =  3  negative de =  12"
# [1] "CMC - ICMP vs HCMPrEF  positive de =  0  negative de =  2"
# [1] "CMC - DCMP vs HCMPpEF  positive de =  156  negative de =  142"
# [1] "CMC - ICMP vs HCMPpEF  positive de =  97  negative de =  202"
# [1] "CMC - HCMPrEF vs HCMPpEF  positive de =  46  negative de =  59"

# %% [markdown]
# # Figure 4E

# %%
DEfile21 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_ICMP__ES_HCMP_Y_OL_pcaplot_outlier_RE_PID_Fixation.interval_KR_Y2023-06-23conditionICMP_conditionES_HCMP"
DEfile22 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_DCMP__ICMP_Y_OL_pcaplot_outlier_RE_PID_Fixation.interval_KR_Y2023-06-23conditionICMP_conditionDCMP"
DEfile23 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_DCMP__ES_HCMP_Y_OL_pcaplot_outlier_RE_PID_Fixation.interval_KR_Y2023-06-23conditionES_HCMP_conditionDCMP"
DEfile24 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_ICMP__NES_HCMP_Y_OL_N_RE_PID_Fixation.interval_KR_Y2023-06-23conditionICMP_conditionNES_HCMP"
DEfile25 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_DCMP__NES_HCMP_Y_OL_pcaplot_outlier_RE_PID_Fixation.interval_KR_Y2023-06-23conditionDCMP_conditionNES_HCMP"
DEfile26 = "fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_Endothelial_cells_ROI_large_Vent_LV_DsSelect_ES_HCMP__NES_HCMP_Y_OL_pcaplot_outlier_RE_PID_Fixation.interval_KR_Y2023-06-23conditionES_HCMP_conditionNES_HCMP"

# %%
DE21 <- read.csv(file.path(getwd(), "results", paste0(DEfile21, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE22 <- read.csv(file.path(getwd(), "results", paste0(DEfile22, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE23 <- read.csv(file.path(getwd(), "results", paste0(DEfile23, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE24 <- read.csv(file.path(getwd(), "results", paste0(DEfile24, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE25 <- read.csv(file.path(getwd(), "results", paste0(DEfile25, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)
DE26 <- read.csv(file.path(getwd(), "results", paste0(DEfile26, ".csv")), row.names = 1, header = TRUE, stringsAsFactors=FALSE)

# %%
for (i in 21:26){
    tmp <- gsub("fSupplT6_DE_SejongIn_Clinical_phenotype_LV_FullROI_N_cellselection_Y_", "", get(paste0("DEfile", i)))
    tmp2 <- gsub("_ROI_large_Vent_LV_DsSelect.*23", "", tmp)
    tmp3 <- gsub("condition", "_", tmp2)
    tmp3 <- gsub(".csv", "", tmp3)
    tmp4 <-get(paste0("DE", i))
    tmp4 <- tmp4 %>% mutate(COI = tmp3) 
    assign(paste0("DE", i), tmp4)
}

# %%
for (i in 21:26){
    tmp4 <-get(paste0("DE", i))
    tmp4 <- tmp4 %>% mutate(Index = 1:nrow(tmp4)) 
    assign(paste0("DE", i), tmp4)
}

# %%
for (i in 21:26){
    tmp4 <-get(paste0("DE", i))
    tmp4$PosIndex[tmp4$logFC > 0 & tmp4$adj.P.Val < 0.05]<-1:nrow(tmp4[tmp4$logFC > 0 & tmp4$adj.P.Val < 0.05,])
    tmp4$NegIndex[tmp4$logFC < 0 & tmp4$adj.P.Val < 0.05]<-1:nrow(tmp4[tmp4$logFC < 0 & tmp4$adj.P.Val < 0.05,])
    assign(paste0("DE", i), tmp4)
}

# %%
# DE_Noseg<-rbind(DE1, DE2, DE3)
# DE_eachcell<-rbind(DE4, DE5, DE6)
# DE_othercell<-rbind(DE7, DE8, DE9)
DE_total3 <- rbind(DE21, DE22, DE23, DE24, DE25, DE26)

# %%
unique(DE_total3$COI )
# Out:
# [1] "Endothelial_cells_ICMP__ES_HCMP"     "Endothelial_cells_ICMP__DCMP"
# [3] "Endothelial_cells_ES_HCMP__DCMP"     "Endothelial_cells_ICMP__NES_HCMP"
# [5] "Endothelial_cells_DCMP__NES_HCMP"    "Endothelial_cells_ES_HCMP__NES_HCMP"

# %%
DE_total3$diffexpressed <- "NO"
DE_total3$diffexpressed[DE_total3$logFC > 0 & DE_total3$adj.P.Val < 0.05] <- "UP"
DE_total3$diffexpressed[DE_total3$logFC < 0 & DE_total3$adj.P.Val < 0.05] <- "DOWN"
DE_total3$delabel <- NA
DE_total3$delabel[DE_total3$diffexpressed!="NO"] <- DE_total3$SYMBOL[DE_total3$diffexpressed!="NO"]
DE_total3$COI <- factor(DE_total3$COI, levels=c('Endothelial_cells_ICMP__DCMP', 
                                               'Endothelial_cells_ES_HCMP__DCMP',
                                               'Endothelial_cells_ICMP__ES_HCMP',
                                               'Endothelial_cells_DCMP__NES_HCMP',
                                               'Endothelial_cells_ICMP__NES_HCMP',
                                               'Endothelial_cells_ES_HCMP__NES_HCMP'))

# %%
DE_total3$COI <- recode_factor(DE_total3$COI, 
                               Endothelial_cells_ICMP__DCMP = "EC - ICMP vs DCMP", 
                                Endothelial_cells_ES_HCMP__DCMP = "EC - HCMPrEF vs DCMP",
                                Endothelial_cells_ICMP__ES_HCMP = "EC - ICMP vs HCMPrEF",
                                Endothelial_cells_DCMP__NES_HCMP = "EC - DCMP vs HCMPpEF",
                                Endothelial_cells_ICMP__NES_HCMP = "EC - ICMP vs HCMPpEF",
                                Endothelial_cells_ES_HCMP__NES_HCMP = "EC - HCMPrEF vs HCMPpEF"
                               )

# %%
options(repr.plot.width=18, repr.plot.height=5)

# %%
ggplot(data=DE_total3, aes(x=COI, y=(-log10(adj.P.Val))*(sign(logFC)), col=diffexpressed, label=delabel)) +
geom_jitter(width=0.02) +
theme_minimal() +
geom_text_repel(size=5
) +
scale_color_manual(values=c("blue", "black", "red"), labels=c('Down-regulated', 'No change', 'Up-regulated')) +
geom_hline(yintercept=c(-log10(0.05), log10(0.05)), col="red") +
geom_hline(yintercept=0, col="black") +
theme(axis.text.x=element_text(angle = 10, hjust=0.5, size=14,face="bold"),
        axis.title=element_text(size=14,face="bold"),
     legend.title=element_blank(),
     legend.text = element_text(size=12),
     ) +
xlab("") +
guides(color = guide_legend(override.aes = list(size = 8)))
# Out:
# Warning message:
# “Removed 76470 rows containing missing values (`geom_text_repel()`).”
# Warning message:
# “ggrepel: 301 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
for (i in levels(DE_total3$COI)){
    posde<-dim(DE_total3[DE_total3$COI==i&is.na(DE_total3$PosIndex)==FALSE,])[1]
    negde<-dim(DE_total3[DE_total3$COI==i&is.na(DE_total3$NegIndex)==FALSE,])[1]
    print(paste(i, " positive de = ", posde, " negative de = ", negde))
    }
# Out:
# [1] "EC - ICMP vs DCMP  positive de =  5  negative de =  1"
# [1] "EC - HCMPrEF vs DCMP  positive de =  2  negative de =  8"
# [1] "EC - ICMP vs HCMPrEF  positive de =  27  negative de =  34"
# [1] "EC - DCMP vs HCMPpEF  positive de =  50  negative de =  55"
# [1] "EC - ICMP vs HCMPpEF  positive de =  33  negative de =  85"
# [1] "EC - HCMPrEF vs HCMPpEF  positive de =  12  negative de =  18"

# %%
sessionInfo()
# Out:
# R version 4.0.0 (2020-04-24)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS:   /opt/applications/R/4.0.0/gnu/lib64/R/lib/libRblas.so
# LAPACK: /opt/applications/R/4.0.0/gnu/lib64/R/lib/libRlapack.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] grid      stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] VennDiagram_1.7.3   futile.logger_1.4.3 lubridate_1.9.2
#  [4] forcats_1.0.0       stringr_1.5.0       dplyr_1.1.0
#  [7] purrr_1.0.1         readr_2.1.4         tidyr_1.3.0
# [10] tibble_3.2.0        tidyverse_2.0.0     ggrepel_0.9.2
# [13] ggplot2_3.4.1
#
# ...
